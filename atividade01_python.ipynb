# %% [markdown]
# <a href="https://colab.research.google.com/github/neemiasbsilva1703-svg/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade01- Introdução ao Python

# %%
print("Ola, mundo!")
# Out:
# Ola, mundo!

# %%
Disciplina  = input("digite o nome da disciplina: ")

print("disciplina: ", Disciplina)
# Out:
# digite o nome da disciplina:  matematica
# disciplina:   matematica
